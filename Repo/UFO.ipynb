# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = 'C:\\DA12\\Projects\\Python\\Projects\\Capstone\\test-capstone\\Data\\archive\\scrubbed.csv'

df = pd.read_excel(file_path,on_bad_lines='warn')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[459], line 3
#       1 file_path = 'C:\\DA12\\Projects\\Python\\Projects\\Capstone\\test-capstone\\Data\\archive\\scrubbed.csv'
# ----> 3 df = pd.read_excel(file_path,on_bad_lines='warn')
#
# TypeError: read_excel() got an unexpected keyword argument 'on_bad_lines'

# %%
len(df)
# Out:
# 80332

# %%
df.head()
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# 3  My older brother and twin sister were leaving ...   1/17/2004  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.4180556
#
#    longitude  day month        year   time        period
# 0  -97.941111  10    10  1949 20:30  20:30  san marcostx
# 1  -98.581082  10    10  1949 21:00  21:00           NaN
# 2   -2.916667  10    10  1955 17:00  17:00           NaN
# 3  -96.645833  10    10  1956 21:00  21:00        ednatx
# 4 -157.803611  10    10  1960 20:00  20:00     kaneohehi

# %%
df.shape
# Out:
# (80332, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              80332 non-null  object
#  1   city                  80332 non-null  object
#  2   state                 74535 non-null  object
#  3   country               70662 non-null  object
#  4   shape                 80332 non-null  object
#  5   duration (seconds)    80332 non-null  object
#  6   duration (hours/min)  80332 non-null  object
#  7   comments              80317 non-null  object
#  8   date posted           80332 non-null  object
#  9   latitude              80332 non-null  object
#  10  longitude             80332 non-null  float64
#  11  day                   80332 non-null  object
#  12  month                 80332 non-null  object
#  13  year                  80332 non-null  object
#  14  time                  80332 non-null  object
#  15  period                55472 non-null  object
# dtypes: float64(1), object(15)
# memory usage: 9.8+ MB

# %%
df[['day','month','year']] = df['datetime'].str.split('/', expand=True)
print(df)
# Out:
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# 1                   7200              1-2 hrs
# 2                     20           20 seconds
# 3                     20             1/2 hour
# 4                    900           15 minutes
# ...                  ...                  ...
# 80327              600.0           10 minutes
# 80328             1200.0           20 minutes
# 80329             1200.0                 hour
# 80330                5.0            5 seconds
# 80331             1020.0           17 minutes
#
#                                                 comments date posted  \
# 0      This event took place in early fall around 194...   4/27/2004
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005
# 2      Green/Orange circular disc over Chester&#44 En...   1/21/2008
# 3      My older brother and twin sister were leaving ...   1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004
# ...                                                  ...         ...
# 80327  Round from the distance/slowly changing colors...   9/30/2013
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...   9/30/2013
# 80329                                       Napa UFO&#44   9/30/2013
# 80330  Saw a five gold lit cicular craft moving fastl...   9/30/2013
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...   9/30/2013
#
#          latitude  longitude  day month        year   time        period
# 0      29.8830556  -97.941111  10    10  1949 20:30  20:30  san marcostx
# 1        29.38421  -98.581082  10    10  1949 21:00  21:00           NaN
# 2            53.2   -2.916667  10    10  1955 17:00  17:00           NaN
# 3      28.9783333  -96.645833  10    10  1956 21:00  21:00        ednatx
# 4      21.4180556 -157.803611  10    10  1960 20:00  20:00     kaneohehi
# ...           ...         ...  ..   ...         ...    ...           ...
# 80327   36.165833  -86.784444   9     9  2013 21:15  21:15           NaN
# 80328   43.613611 -116.202500   9     9  2013 22:00  22:00           NaN
# 80329   38.297222 -122.284444   9     9  2013 22:00  22:00           NaN
# 80330   38.901111  -77.265556   9     9  2013 22:20  22:20           NaN
# 80331   35.652778  -97.477778   9     9  2013 23:00  23:00           NaN
#
# [80332 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              80332 non-null  object
#  1   city                  80332 non-null  object
#  2   state                 74535 non-null  object
#  3   country               70662 non-null  object
#  4   shape                 80332 non-null  object
#  5   duration (seconds)    80332 non-null  object
#  6   duration (hours/min)  80332 non-null  object
#  7   comments              80317 non-null  object
#  8   date posted           80332 non-null  object
#  9   latitude              80332 non-null  object
#  10  longitude             80332 non-null  float64
#  11  day                   80332 non-null  object
#  12  month                 80332 non-null  object
#  13  year                  80332 non-null  object
#  14  time                  80332 non-null  object
#  15  period                55472 non-null  object
# dtypes: float64(1), object(15)
# memory usage: 9.8+ MB

# %%
df['shape'] = df['shape'].astype(str)

# %%
Shape_Duration = df[['shape','duration (seconds)']]
Shape_Duration
# Out:
#           shape duration (seconds)
# 0      cylinder               2700
# 1         light               7200
# 2        circle                 20
# 3        circle                 20
# 4         light                900
# ...         ...                ...
# 80327     light              600.0
# 80328    circle             1200.0
# 80329     other             1200.0
# 80330    circle                5.0
# 80331     cigar             1020.0
#
# [80332 rows x 2 columns]

# %%
plt.hist(Shape_Duration['shape'], bins = 40, edgecolor='black', range=[10, 15])

plt.xlabel('Shape', fontsize=10) 
plt.ylabel('Duration', fontsize=10) 
plt.title('Duration Per UFO Shape')

plt.show()

# %%
df
# Out:
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# 1                   7200              1-2 hrs
# 2                     20           20 seconds
# 3                     20             1/2 hour
# 4                    900           15 minutes
# ...                  ...                  ...
# 80327              600.0           10 minutes
# 80328             1200.0           20 minutes
# 80329             1200.0                 hour
# 80330                5.0            5 seconds
# 80331             1020.0           17 minutes
#
#                                                 comments date posted  \
# 0      This event took place in early fall around 194...   4/27/2004
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005
# 2      Green/Orange circular disc over Chester&#44 En...   1/21/2008
# 3      My older brother and twin sister were leaving ...   1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004
# ...                                                  ...         ...
# 80327  Round from the distance/slowly changing colors...   9/30/2013
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...   9/30/2013
# 80329                                       Napa UFO&#44   9/30/2013
# 80330  Saw a five gold lit cicular craft moving fastl...   9/30/2013
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...   9/30/2013
#
#          latitude  longitude  day month        year   time        period
# 0      29.8830556  -97.941111  10    10  1949 20:30  20:30  san marcostx
# 1        29.38421  -98.581082  10    10  1949 21:00  21:00           NaN
# 2            53.2   -2.916667  10    10  1955 17:00  17:00           NaN
# 3      28.9783333  -96.645833  10    10  1956 21:00  21:00        ednatx
# 4      21.4180556 -157.803611  10    10  1960 20:00  20:00     kaneohehi
# ...           ...         ...  ..   ...         ...    ...           ...
# 80327   36.165833  -86.784444   9     9  2013 21:15  21:15           NaN
# 80328   43.613611 -116.202500   9     9  2013 22:00  22:00           NaN
# 80329   38.297222 -122.284444   9     9  2013 22:00  22:00           NaN
# 80330   38.901111  -77.265556   9     9  2013 22:20  22:20           NaN
# 80331   35.652778  -97.477778   9     9  2013 23:00  23:00           NaN
#
# [80332 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              80332 non-null  object
#  1   city                  80332 non-null  object
#  2   state                 74535 non-null  object
#  3   country               70662 non-null  object
#  4   shape                 80332 non-null  object
#  5   duration (seconds)    80332 non-null  object
#  6   duration (hours/min)  80332 non-null  object
#  7   comments              80317 non-null  object
#  8   date posted           80332 non-null  object
#  9   latitude              80332 non-null  object
#  10  longitude             80332 non-null  float64
#  11  day                   80332 non-null  object
#  12  month                 80332 non-null  object
#  13  year                  80332 non-null  object
#  14  time                  80332 non-null  object
#  15  period                55472 non-null  object
# dtypes: float64(1), object(15)
# memory usage: 9.8+ MB

# %%
df_rename = df.rename(columns={'shape': 'UFO_Shape','duration (hours/min)': 'duration_Hour', 'duration (seconds)': 'duration_Seconds' })
df_rename
# Out:
#                datetime                  city state country UFO_Shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration_Seconds duration_Hour  \
# 0                 2700    45 minutes
# 1                 7200       1-2 hrs
# 2                   20    20 seconds
# 3                   20      1/2 hour
# 4                  900    15 minutes
# ...                ...           ...
# 80327            600.0    10 minutes
# 80328           1200.0    20 minutes
# 80329           1200.0          hour
# 80330              5.0     5 seconds
# 80331           1020.0    17 minutes
#
#                                                 comments date posted  \
# 0      This event took place in early fall around 194...   4/27/2004
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005
# 2      Green/Orange circular disc over Chester&#44 En...   1/21/2008
# 3      My older brother and twin sister were leaving ...   1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004
# ...                                                  ...         ...
# 80327  Round from the distance/slowly changing colors...   9/30/2013
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...   9/30/2013
# 80329                                       Napa UFO&#44   9/30/2013
# 80330  Saw a five gold lit cicular craft moving fastl...   9/30/2013
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...   9/30/2013
#
#          latitude  longitude  day month        year   time        period
# 0      29.8830556  -97.941111  10    10  1949 20:30  20:30  san marcostx
# 1        29.38421  -98.581082  10    10  1949 21:00  21:00           NaN
# 2            53.2   -2.916667  10    10  1955 17:00  17:00           NaN
# 3      28.9783333  -96.645833  10    10  1956 21:00  21:00        ednatx
# 4      21.4180556 -157.803611  10    10  1960 20:00  20:00     kaneohehi
# ...           ...         ...  ..   ...         ...    ...           ...
# 80327   36.165833  -86.784444   9     9  2013 21:15  21:15           NaN
# 80328   43.613611 -116.202500   9     9  2013 22:00  22:00           NaN
# 80329   38.297222 -122.284444   9     9  2013 22:00  22:00           NaN
# 80330   38.901111  -77.265556   9     9  2013 22:20  22:20           NaN
# 80331   35.652778  -97.477778   9     9  2013 23:00  23:00           NaN
#
# [80332 rows x 16 columns]

# %%
## Had to rename the columns to a more readable format ##

# %%
df_rename['duration_Seconds'] = df_rename['duration_Seconds'].str.replace(r'\W', '', regex=True)
df_rename
# Out:
#                datetime                  city state country UFO_Shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration_Seconds duration_Hour  \
# 0                 2700    45 minutes
# 1                 7200       1-2 hrs
# 2                   20    20 seconds
# 3                   20      1/2 hour
# 4                  900    15 minutes
# ...                ...           ...
# 80327              NaN    10 minutes
# 80328              NaN    20 minutes
# 80329              NaN          hour
# 80330              NaN     5 seconds
# 80331              NaN    17 minutes
#
#                                                 comments date posted  \
# 0      This event took place in early fall around 194...   4/27/2004
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005
# 2      Green/Orange circular disc over Chester&#44 En...   1/21/2008
# 3      My older brother and twin sister were leaving ...   1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004
# ...                                                  ...         ...
# 80327  Round from the distance/slowly changing colors...   9/30/2013
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...   9/30/2013
# 80329                                       Napa UFO&#44   9/30/2013
# 80330  Saw a five gold lit cicular craft moving fastl...   9/30/2013
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...   9/30/2013
#
#          latitude  longitude  day month        year   time        period
# 0      29.8830556  -97.941111  10    10  1949 20:30  20:30  san marcostx
# 1        29.38421  -98.581082  10    10  1949 21:00  21:00           NaN
# 2            53.2   -2.916667  10    10  1955 17:00  17:00           NaN
# 3      28.9783333  -96.645833  10    10  1956 21:00  21:00        ednatx
# 4      21.4180556 -157.803611  10    10  1960 20:00  20:00     kaneohehi
# ...           ...         ...  ..   ...         ...    ...           ...
# 80327   36.165833  -86.784444   9     9  2013 21:15  21:15           NaN
# 80328   43.613611 -116.202500   9     9  2013 22:00  22:00           NaN
# 80329   38.297222 -122.284444   9     9  2013 22:00  22:00           NaN
# 80330   38.901111  -77.265556   9     9  2013 22:20  22:20           NaN
# 80331   35.652778  -97.477778   9     9  2013 23:00  23:00           NaN
#
# [80332 rows x 16 columns]

# %%
## Had to strip the ' symbol out of the duration_Seconds column ##

# %%
df_rename['duration_Seconds'] = df_rename['duration_Seconds'].astype(float)
df_rename.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   datetime          80332 non-null  object
#  1   city              80332 non-null  object
#  2   state             74535 non-null  object
#  3   country           70662 non-null  object
#  4   UFO_Shape         80332 non-null  object
#  5   duration_Seconds  65536 non-null  float64
#  6   duration_Hour     80332 non-null  object
#  7   comments          80317 non-null  object
#  8   date posted       80332 non-null  object
#  9   latitude          80332 non-null  object
#  10  longitude         80332 non-null  float64
#  11  day               80332 non-null  object
#  12  month             80332 non-null  object
#  13  year              80332 non-null  object
#  14  time              80332 non-null  object
#  15  period            55472 non-null  object
# dtypes: float64(2), object(14)
# memory usage: 9.8+ MB

# %%
UFO_Count = df_rename['UFO_Shape'].value_counts().reset_index().sort_values(by='count', ascending =False).nlargest(n=5, columns = 'count')
UFO_Count.head()
# Out:
#   UFO_Shape  count
# 0     light  16565
# 1  triangle   7865
# 2    circle   7608
# 3  fireball   6208
# 4     other   5649

# %%
## The UFO shape with the most amount of counts would be the "light" ##

# %%
sns.barplot(data=UFO_Count, x= 'UFO_Shape', y= 'count')
# Out:
# <Axes: xlabel='UFO_Shape', ylabel='count'>

# %%
Duration_UFO = df_rename[['UFO_Shape', 'duration_Seconds']]
Duration_UFO.head()
# Out:
#   UFO_Shape  duration_Seconds
# 0  cylinder            2700.0
# 1     light            7200.0
# 2    circle              20.0
# 3    circle              20.0
# 4     light             900.0

# %%
df_rename['duration_Seconds'].agg(['min', 'max'])
# Out:
# min           1.0
# max    97836000.0
# Name: duration_Seconds, dtype: float64

# %%
Longest_Duration = Duration_UFO.loc[Duration_UFO['duration_Seconds'] == 97836000.0]
Longest_Duration
# Out:
#     UFO_Shape  duration_Seconds
# 559    sphere        97836000.0

# %%
## The UFO shape with the longest duration of sightings out of all the shapes is the "sphere" ##

# %%
Average_Duration = Duration_UFO['duration_Seconds'].mean()
Average_Duration
# Out:
# 8612.701721191406

# %%
## The avergae duration for UFO sighting is roughly 8,612 seconds ##

# %%
df_rename.head()
# Out:
#            datetime                  city state country UFO_Shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#    duration_Seconds duration_Hour  \
# 0            2700.0    45 minutes
# 1            7200.0       1-2 hrs
# 2              20.0    20 seconds
# 3              20.0      1/2 hour
# 4             900.0    15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# 3  My older brother and twin sister were leaving ...   1/17/2004  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.4180556
#
#    longitude  day month        year   time
# 0  -97.941111  10    10  1949 20:30  20:30
# 1  -98.581082  10    10  1949 21:00  21:00
# 2   -2.916667  10    10  1955 17:00  17:00
# 3  -96.645833  10    10  1956 21:00  21:00
# 4 -157.803611  10    10  1960 20:00  20:00

# %%
df_dropped = df_rename.dropna()

# %%
UFO_Place = df_dropped[['UFO_Shape','state', 'datetime']]
UFO_Place.dropna()
# Out:
#        UFO_Shape state          datetime
# 0       cylinder    tx  10/10/1949 20:30
# 3         circle    tx  10/10/1956 21:00
# 4          light    hi  10/10/1960 20:00
# 5         sphere    tn  10/10/1961 19:00
# 7           disk    ct  10/10/1965 23:45
# ...          ...   ...               ...
# 65531      light    ny   8/12/2011 23:15
# 65532     sphere    la   8/12/2011 23:27
# 65533    unknown    ca   8/12/2012 00:00
# 65534     circle    il   8/12/2012 00:00
# 65535  formation    wi   8/12/2012 00:15
#
# [55472 rows x 3 columns]

# %%
df[['Year', 'time']] = df['year'].str.split(expand=True)

# %%
df
# Out:
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# 1                   7200              1-2 hrs
# 2                     20           20 seconds
# 3                     20             1/2 hour
# 4                    900           15 minutes
# ...                  ...                  ...
# 80327              600.0           10 minutes
# 80328             1200.0           20 minutes
# 80329             1200.0                 hour
# 80330                5.0            5 seconds
# 80331             1020.0           17 minutes
#
#                                                 comments date posted  \
# 0      This event took place in early fall around 194...   4/27/2004
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005
# 2      Green/Orange circular disc over Chester&#44 En...   1/21/2008
# 3      My older brother and twin sister were leaving ...   1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004
# ...                                                  ...         ...
# 80327  Round from the distance/slowly changing colors...   9/30/2013
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...   9/30/2013
# 80329                                       Napa UFO&#44   9/30/2013
# 80330  Saw a five gold lit cicular craft moving fastl...   9/30/2013
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...   9/30/2013
#
#          latitude  longitude  day month        year   time        period  Year
# 0      29.8830556  -97.941111  10    10  1949 20:30  20:30  san marcostx  1949
# 1        29.38421  -98.581082  10    10  1949 21:00  21:00           NaN  1949
# 2            53.2   -2.916667  10    10  1955 17:00  17:00           NaN  1955
# 3      28.9783333  -96.645833  10    10  1956 21:00  21:00        ednatx  1956
# 4      21.4180556 -157.803611  10    10  1960 20:00  20:00     kaneohehi  1960
# ...           ...         ...  ..   ...         ...    ...           ...   ...
# 80327   36.165833  -86.784444   9     9  2013 21:15  21:15           NaN  2013
# 80328   43.613611 -116.202500   9     9  2013 22:00  22:00           NaN  2013
# 80329   38.297222 -122.284444   9     9  2013 22:00  22:00           NaN  2013
# 80330   38.901111  -77.265556   9     9  2013 22:20  22:20           NaN  2013
# 80331   35.652778  -97.477778   9     9  2013 23:00  23:00           NaN  2013
#
# [80332 rows x 17 columns]

# %%
year_dropped = df.drop('year', axis =1)

# %%
Updated_df = year_dropped.drop('period', axis =1)

# %%
Updated_df
# Out:
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# 1                   7200              1-2 hrs
# 2                     20           20 seconds
# 3                     20             1/2 hour
# 4                    900           15 minutes
# ...                  ...                  ...
# 80327              600.0           10 minutes
# 80328             1200.0           20 minutes
# 80329             1200.0                 hour
# 80330                5.0            5 seconds
# 80331             1020.0           17 minutes
#
#                                                 comments date posted  \
# 0      This event took place in early fall around 194...   4/27/2004
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005
# 2      Green/Orange circular disc over Chester&#44 En...   1/21/2008
# 3      My older brother and twin sister were leaving ...   1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004
# ...                                                  ...         ...
# 80327  Round from the distance/slowly changing colors...   9/30/2013
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...   9/30/2013
# 80329                                       Napa UFO&#44   9/30/2013
# 80330  Saw a five gold lit cicular craft moving fastl...   9/30/2013
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...   9/30/2013
#
#          latitude  longitude  day month   time  Year
# 0      29.8830556  -97.941111  10    10  20:30  1949
# 1        29.38421  -98.581082  10    10  21:00  1949
# 2            53.2   -2.916667  10    10  17:00  1955
# 3      28.9783333  -96.645833  10    10  21:00  1956
# 4      21.4180556 -157.803611  10    10  20:00  1960
# ...           ...         ...  ..   ...    ...   ...
# 80327   36.165833  -86.784444   9     9  21:15  2013
# 80328   43.613611 -116.202500   9     9  22:00  2013
# 80329   38.297222 -122.284444   9     9  22:00  2013
# 80330   38.901111  -77.265556   9     9  22:20  2013
# 80331   35.652778  -97.477778   9     9  23:00  2013
#
# [80332 rows x 15 columns]

# %%
UFO_Year = Updated_df[['shape', 'time', 'Year']]
UFO_Year
# Out:
#           shape   time  Year
# 0      cylinder  20:30  1949
# 1         light  21:00  1949
# 2        circle  17:00  1955
# 3        circle  21:00  1956
# 4         light  20:00  1960
# ...         ...    ...   ...
# 80327     light  21:15  2013
# 80328    circle  22:00  2013
# 80329     other  22:00  2013
# 80330    circle  22:20  2013
# 80331     cigar  23:00  2013
#
# [80332 rows x 3 columns]

# %%
max = UFO_Year.groupby('Year')['shape'].count()
max
# Out:
# Year
# 1906       1
# 1910       2
# 1916       1
# 1920       1
# 1925       1
#         ...
# 2010    4283
# 2011    5107
# 2012    7357
# 2013    7037
# 2014    2260
# Name: shape, Length: 87, dtype: int64

# %%
plt.plot( 'year', 'shape', data=df)
