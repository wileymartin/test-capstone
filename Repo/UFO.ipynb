# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = 'C:\\DA12\\Projects\\Python\\Projects\\Capstone\\test-capstone\\Data\\archive\\scrubbed.csv'

df = pd.read_csv(file_path,on_bad_lines='warn')
# Out:
# C:\Users\wiley\AppData\Local\Temp\ipykernel_31632\946520165.py:3: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path,on_bad_lines='warn')

# %%
len(df)
# Out:
# 80332

# %%
df.head()
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# ...

# %%
df.shape
# Out:
# (80332, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              80332 non-null  object
#  1   city                  80332 non-null  object
#  2   state                 74535 non-null  object
#  3   country               70662 non-null  object
#  4   shape                 78400 non-null  object
#  5   duration (seconds)    80332 non-null  object
#  6   duration (hours/min)  80332 non-null  object
#  7   comments              80317 non-null  object
#  8   date posted           80332 non-null  object
#  9   latitude              80332 non-null  object
#  10  longitude             80332 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 6.7+ MB

# %%
df[['day','month','year']] = df['datetime'].str.split('/', expand=True)
print(df)
# Out:
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              80332 non-null  object
#  1   city                  80332 non-null  object
#  2   state                 74535 non-null  object
#  3   country               70662 non-null  object
#  4   shape                 78400 non-null  object
#  5   duration (seconds)    80332 non-null  object
#  6   duration (hours/min)  80332 non-null  object
#  7   comments              80317 non-null  object
#  8   date posted           80332 non-null  object
#  9   latitude              80332 non-null  object
#  10  longitude             80332 non-null  float64
#  11  day                   80332 non-null  object
#  12  month                 80332 non-null  object
#  13  year                  80332 non-null  object
# dtypes: float64(1), object(13)
# ...

# %%
df['shape'] = df['shape'].astype(str)

# %%
Shape_Duration = df[['shape','duration (seconds)']]
Shape_Duration
# Out:
#           shape duration (seconds)
# 0      cylinder               2700
# 1         light               7200
# 2        circle                 20
# 3        circle                 20
# 4         light                900
# ...         ...                ...
# 80327     light              600.0
# 80328    circle             1200.0
# 80329     other             1200.0
# 80330    circle                5.0
# 80331     cigar             1020.0
#
# [80332 rows x 2 columns]

# %%
plt.hist(Shape_Duration['shape'], bins = 10, edgecolor='black', range=[10, 15])

plt.xlabel('Shape', fontsize=10) 
plt.ylabel('Duration', fontsize=10) 
plt.title('Duration Per UFO Shape')

plt.show()

# %%
df
# Out:
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# ...

# %%
df['time'] = df['year'].str.split('  ', expand=True)
df_rename
# Out:
#                datetime                  city state country UFO_Shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration_Seconds duration_Hour  \
# 0                 2700    45 minutes
# 1                 7200       1-2 hrs
# ...

# %%
df_rename = df.rename(columns={'shape': 'UFO_Shape','duration (hours/min)': 'duration_Hour', 'duration (seconds)': 'duration_Seconds' })
df_rename
# Out:
#                datetime                  city state country UFO_Shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration_Seconds duration_Hour  \
# 0                 2700    45 minutes
# 1                 7200       1-2 hrs
# ...

# %%
UFO_Count = df_rename['UFO_Shape'].value_counts().reset_index().sort_values(by='count', ascending =False).nlargest(n=5, columns = 'count')
UFO_Count.head()
# Out:
#   UFO_Shape  count
# 0     light  16565
# 1  triangle   7865
# 2    circle   7608
# 3  fireball   6208
# 4     other   5649

# %%
sns.barplot(data=UFO_Count, x= 'UFO_Shape', y= 'count')
# Out:
# <Axes: xlabel='UFO_Shape', ylabel='count'>

# %%
Duration_UFO = df_rename[['UFO_Shape', 'duration_Seconds']]
Duration_UFO.head()
# Out:
#   UFO_Shape duration_Seconds
# 0  cylinder             2700
# 1     light             7200
# 2    circle               20
# 3    circle               20
# 4     light              900

# %%
Duration_UFO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   UFO_Shape         80332 non-null  object
#  1   duration_Seconds  80332 non-null  object
# dtypes: object(2)
# memory usage: 1.2+ MB

# %%
input_str = Duration_UFO['duration_Seconds']
if input_str.isdigit():
    print("Output Integer is:")
    myInt=int(input_str)
    print(myInt)
else:
    print("Input cannot be converted into Integer.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31632\2561015413.py in ?()
#       1 input_str = Duration_UFO['duration_Seconds']
# ----> 2 if input_str.isdigit():
#       3     print("Output Integer is:")
#       4     myInt=int(input_str)
#       5     print(myInt)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'isdigit'

# %%
df_rename['duration_Seconds'].agg(['min', 'max'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[208], line 1
# ----> 1 df_rename['duration_Seconds'].agg(['min', 'max'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4766, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4763     func = dict(kwargs.items())
#    4765 op = SeriesApply(self, func, args=args, kwargs=kwargs)
# -> 4766 result = op.agg()
#    4767 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1430, in SeriesApply.agg(self)
#    1429 def agg(self):
# -> 1430     result = super().agg()
#    1431     if result is None:
#    1432         obj = self.obj
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:193, in Apply.agg(self)
#     190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
# --> 193     return self.agg_list_like()
# ...

# %%
Longest_Duration = Duration_UFO.loc[Duration_UFO['duration (seconds)'] == 900]
result
# Out:
#        UFO_Shape duration_Seconds
# 65590   fireball            900.0
# 65599    unknown            900.0
# 65608  formation            900.0
# 65614        nan            900.0
# 65628   triangle            900.0
# ...          ...              ...
# 80235   triangle            900.0
# 80237        nan            900.0
# 80239      other            900.0
# 80305    chevron            900.0
# 80311      flash            900.0
#
# [744 rows x 2 columns]

# %%
Duration_UFO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   UFO_Shape         80332 non-null  object
#  1   duration_Seconds  80332 non-null  object
# dtypes: object(2)
# memory usage: 1.2+ MB

# %%
Average_Duration = Duration_UFO['duration (seconds)'].mean()
Average_Duration
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[180], line 1
# ----> 1 Average_Duration = Duration_UFO['duration (seconds)'].mean()
#       2 Average_Duration
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
# ...
