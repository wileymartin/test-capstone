# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
file_path = 'C:\\DA12\\Projects\\Python\\Projects\\Capstone\\Data\\archive\\Meteorite_Landings.csv'

df = pd.read_csv(file_path)

# %%
df
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong             GeoLocation
# ...

# %%
Valid_df = df[df['nametype'] == "Valid"]
Valid_df
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong             GeoLocation
# ...

# %%
Fallen_Valid = Valid_df[Valid_df['fall'] == "Fell"]
Fallen_Valid
# Out:
#           name     id nametype     recclass  mass (g)  fall    year    reclat  \
# 0       Aachen      1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1       Aarhus      2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2         Abee      6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3     Acapulco     10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4      Achiras    370    Valid           L6     780.0  Fell  1902.0 -33.16667
# ...        ...    ...      ...          ...       ...   ...     ...       ...
# 1106  Zhuanghe  30408    Valid           H5    2900.0  Fell  1976.0  39.66667
# 1107     Zmenj  30411    Valid    Howardite     246.0  Fell  1858.0  51.83333
# 1108     Zomba  30412    Valid           L6    7500.0  Fell  1899.0 -15.18333
# 1109   Zsadany  30413    Valid           H5     552.0  Fell  1875.0  46.93333
# 1110   Zvonkov  30415    Valid           H6    2568.0  Fell  1955.0  50.20000
#
# ...

# %%
Found_Valid = Valid_df[Valid_df['fall'] == "Found"]
Found_Valid
# Out:
#                         name     id nametype              recclass  mass (g)  \
# 37     Northwest Africa 5815  50693    Valid                    L5     256.8
# 520      Cumulus Hills 04075  32531    Valid             Pallasite       9.6
# 757     Dominion Range 03239  32591    Valid                    L6      69.5
# 804     Dominion Range 03240  32592    Valid                   LL5     290.9
# 1111                   Abajo      4    Valid                    H5     331.0
# ...                      ...    ...      ...                   ...       ...
# 45711             Zillah 002  31356    Valid               Eucrite     172.0
# 45712                 Zinder  30409    Valid  Pallasite, ungrouped      46.0
# 45713                   Zlin  30410    Valid                    H4       3.3
# 45714              Zubkovsky  31357    Valid                    L6    2167.0
# 45715             Zulu Queen  30414    Valid                  L3.7     200.0
#
# ...

# %%
Found_Count = Valid_df['nametype'].value_counts().reset_index().sort_values(by='count', ascending =False).nlargest(n=5, columns = 'count')
Found_Count.head()
# Out:
#   nametype  count
# 0    Valid  45641

# %%
Found_Count = df['nametype'].value_counts().reset_index().sort_values(by='count', ascending =False).nlargest(n=5, columns = 'count')
Found_Count.head()
# Out:
#   nametype  count
# 0    Valid  45641
# 1   Relict     75

# %%
sns.barplot(data=Found_Count, x= 'nametype', y= 'count')
# Out:
# <Axes: xlabel='nametype', ylabel='count'>

# %%
df[['name', 'mass (g)']].head()
# Out:
#        name  mass (g)
# 0    Aachen      21.0
# 1    Aarhus     720.0
# 2      Abee  107000.0
# 3  Acapulco    1914.0
# 4   Achiras     780.0

# %%
Mass_df = df[['name', 'mass (g)']]
Mass_df
# Out:
#              name  mass (g)
# 0          Aachen      21.0
# 1          Aarhus     720.0
# 2            Abee  107000.0
# 3        Acapulco    1914.0
# 4         Achiras     780.0
# ...           ...       ...
# 45711  Zillah 002     172.0
# 45712      Zinder      46.0
# 45713        Zlin       3.3
# 45714   Zubkovsky    2167.0
# 45715  Zulu Queen     200.0
#
# [45716 rows x 2 columns]

# %%
Mass_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      45716 non-null  object
#  1   mass (g)  45585 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 714.4+ KB

# %%
Mass_df['mass (g)'].agg(['min', 'max'])
# Out:
# min           0.0
# max    60000000.0
# Name: mass (g), dtype: float64

# %%
Mean_df = Mass_df['mass (g)'].mean()
Mean_df
# Out:
# 13278.078548601512
